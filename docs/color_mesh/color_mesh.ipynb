# %% [markdown]
# # 彩色网格

# %% [markdown]
# ## 一、介绍
# 彩色网格主要分为两类：
# 1. 彩色顶点网格：网格顶点带有颜色，三角形的颜色由网格顶点颜色插值得到。网格的色彩分辨率等于顶点分辨率。
# 2. 彩色贴图网格：网格的三角形的颜色对应于图像的一个三角片。网格的色彩分辨率等于图像的色彩分辨率。
#
# 对彩色顶点网格来说，当网格顶点比较少时，色彩信息会损失。彩色贴图网格的色彩分辨率取决于**纹理贴图的分辨率**，与网格顶点分辨率无关。
# 因此同样的网格，纹理贴图方式可以存储高于网格分辨率的色彩信息。

# %% [markdown]
# ##### 1. 彩色顶点网格

# %%
from PIL import Image
display(Image.open("../../resources/color_mesh/vertex_color.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=866x597 at 0x1737EE1BFC8>

# %% [markdown]
# ##### 2. 彩色纹理网格

# %%
from PIL import Image
display(Image.open("../../resources/color_mesh/texture_color.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=890x573 at 0x1737F01AF88>

# %% [markdown]
# ## 二、纹理贴图网格的制作
# 制作纹理贴图网格最重要的步骤就是找到网格顶点和图像像素的对应关系，简称**点像对应**。有了网格，图片以及点像对应信息，就可以制作出纹理贴图。另外，不同帧同一点对应的纹理之间可能有色差，这时需要通过图像处理技术进行纹理融合。

# %% [markdown]
# ## 三、参考资料
# [1] [彩色网格-知乎](https://zhuanlan.zhihu.com/p/85833483)
